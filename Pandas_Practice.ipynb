# %%
import pandas as pd

# %% [markdown]
# ## 1. Purchase DataFrame.

# %%
df_data=pd.read_csv('Purchase_Data.csv')

# %%
df_data.head()
# Out:
#    invoice_number   invoice_time store_id  product_id  category_id  num_item  \
# 0    2.020000e+11  7/15/15 10:45     G816     7000300       210101       1.0
# 1    2.020000e+11  7/15/15 12:16     G816     7070884        70203       1.0
# 2    2.020000e+11  7/15/15 12:16     G816     7070884        70203       1.0
# 3    2.020000e+11  7/15/15 12:16     G816     7070891        70401       1.0
# 4    2.020000e+11  7/15/15 12:16     G816     7090363        70401       1.0
#
#    price
# 0    2.0
# 1    2.0
# 2    2.0
# 3    6.0
# 4    6.0

# %%
df_data.dtypes
# Out:
# invoice_number    float64
# invoice_time       object
# store_id           object
# product_id          int64
# category_id         int64
# num_item          float64
# price             float64
# dtype: object

# %%
result_1=df_data.loc[:,['invoice_number','invoice_time']]

# %%
result_1.head()
# Out:
#    invoice_number   invoice_time
# 0    2.020000e+11  7/15/15 10:45
# 1    2.020000e+11  7/15/15 12:16
# 2    2.020000e+11  7/15/15 12:16
# 3    2.020000e+11  7/15/15 12:16
# 4    2.020000e+11  7/15/15 12:16

# %%
result_2=df_data.loc[:1,:]

# %%
result_2
# Out:
#    invoice_number   invoice_time store_id  product_id  category_id  num_item  \
# 0    2.020000e+11  7/15/15 10:45     G816     7000300       210101       1.0
# 1    2.020000e+11  7/15/15 12:16     G816     7070884        70203       1.0
#
#    price
# 0    2.0
# 1    2.0

# %%
result_3=df_data.loc[:3,['invoice_number','invoice_time','store_id','product_id','category_id']]

# %%
result_3
# Out:
#    invoice_number   invoice_time store_id  product_id  category_id
# 0    2.020000e+11  7/15/15 10:45     G816     7000300       210101
# 1    2.020000e+11  7/15/15 12:16     G816     7070884        70203
# 2    2.020000e+11  7/15/15 12:16     G816     7070884        70203
# 3    2.020000e+11  7/15/15 12:16     G816     7070891        70401

# %%
result_4=df_data.loc[[0,4,6],['invoice_time','price']]

# %%
result_4
# Out:
#     invoice_time  price
# 0  7/15/15 10:45    2.0
# 4  7/15/15 12:16    6.0
# 6  7/15/15 15:28    2.0

# %%
num_rows=len(df_data)
print(num_rows)
# Out:
# 5382

# %%
df_data.tail(1)
# Out:
#       invoice_number  invoice_time store_id  product_id  category_id  \
# 5381    2.020000e+11  9/5/15 23:38     G619    23030206       210101
#
#       num_item  price
# 5381       1.0    2.0

# %%
df_data
# Out:
#       invoice_number   invoice_time store_id  product_id  category_id  \
# 0       2.020000e+11  7/15/15 10:45     G816     7000300       210101
# 1       2.020000e+11  7/15/15 12:16     G816     7070884        70203
# 2       2.020000e+11  7/15/15 12:16     G816     7070884        70203
# 3       2.020000e+11  7/15/15 12:16     G816     7070891        70401
# 4       2.020000e+11  7/15/15 12:16     G816     7090363        70401
# ...              ...            ...      ...         ...          ...
# 5377    2.020000e+11   9/5/15 23:07      300     7308017       210101
# 5378    2.020000e+11   9/5/15 23:23     G619     7070891        70401
# 5379    2.020000e+11   9/5/15 23:24     G619     7071096        70201
# 5380    2.020000e+11   9/5/15 23:32     G619    15000231        70301
# 5381    2.020000e+11   9/5/15 23:38     G619    23030206       210101
#
#       num_item  price
# 0          1.0    2.0
# 1          1.0    2.0
# 2          1.0    2.0
# 3          1.0    6.0
# ...

# %%
#making a copy of the df containing the number values only for future exercises. (named num_rows)

# %%
num_rows=df_data.drop('invoice_time',axis=1)

# %%
num_rows=num_rows.drop('store_id',axis=1)

# %%
num_rows.head()
# Out:
#    invoice_number  product_id  category_id  num_item  price
# 0    2.020000e+11     7000300       210101       1.0    2.0
# 1    2.020000e+11     7070884        70203       1.0    2.0
# 2    2.020000e+11     7070884        70203       1.0    2.0
# 3    2.020000e+11     7070891        70401       1.0    6.0
# 4    2.020000e+11     7090363        70401       1.0    6.0

# %%
print(num_rows.iloc[-1])
# Out:
# invoice_number    2.020000e+11
# product_id        2.303021e+07
# category_id       2.101010e+05
# num_item          1.000000e+00
# price             2.000000e+00
# Name: 5381, dtype: float64

# %%
avg_price=num_rows.price.mean()

# %%
avg_price
# Out:
# 3.1920522110741363

# %%
max_price=num_rows.price.max()

# %%
max_price
# Out:
# 6.01

# %%
x=num_rows.iloc[:,3:]

# %%
x=x.mean()

# %%
x
# Out:
# num_item    1.298309
# price       3.192052
# dtype: float64

# %%
avg_num_items=x.iloc[0]

# %%
avg_num_items
# Out:
# 1.2983091787439613

# %%
avg_price=x.iloc[1]

# %%
avg_price
# Out:
# 3.1920522110741363

# %%
num_rows
# Out:
#       invoice_number  product_id  category_id  num_item  price
# 0       2.020000e+11     7000300       210101       1.0    2.0
# 1       2.020000e+11     7070884        70203       1.0    2.0
# 2       2.020000e+11     7070884        70203       1.0    2.0
# 3       2.020000e+11     7070891        70401       1.0    6.0
# 4       2.020000e+11     7090363        70401       1.0    6.0
# ...              ...         ...          ...       ...    ...
# 5377    2.020000e+11     7308017       210101       1.0    3.0
# 5378    2.020000e+11     7070891        70401       1.0    6.0
# 5379    2.020000e+11     7071096        70201       1.0    5.0
# 5380    2.020000e+11    15000231        70301       2.0    2.0
# 5381    2.020000e+11    23030206       210101       1.0    2.0
#
# [5382 rows x 5 columns]

# %%
num_rows['total']=num_rows['num_item']*num_rows['price']

# %%
num_rows
# Out:
#       invoice_number  product_id  category_id  num_item  price  total
# 0       2.020000e+11     7000300       210101       1.0    2.0    2.0
# 1       2.020000e+11     7070884        70203       1.0    2.0    2.0
# 2       2.020000e+11     7070884        70203       1.0    2.0    2.0
# 3       2.020000e+11     7070891        70401       1.0    6.0    6.0
# 4       2.020000e+11     7090363        70401       1.0    6.0    6.0
# ...              ...         ...          ...       ...    ...    ...
# 5377    2.020000e+11     7308017       210101       1.0    3.0    3.0
# 5378    2.020000e+11     7070891        70401       1.0    6.0    6.0
# 5379    2.020000e+11     7071096        70201       1.0    5.0    5.0
# 5380    2.020000e+11    15000231        70301       2.0    2.0    4.0
# 5381    2.020000e+11    23030206       210101       1.0    2.0    2.0
#
# [5382 rows x 6 columns]

# %%
x=num_rows['total'].nlargest(3)

# %%
x
# Out:
# 4510    348.0
# 3784     72.0
# 4288     72.0
# Name: total, dtype: float64

# %%
x.mean()
# Out:
# 164.0

# %%
df_data
# Out:
#       invoice_number   invoice_time store_id  product_id  category_id  \
# 0       2.020000e+11  7/15/15 10:45     G816     7000300       210101
# 1       2.020000e+11  7/15/15 12:16     G816     7070884        70203
# 2       2.020000e+11  7/15/15 12:16     G816     7070884        70203
# 3       2.020000e+11  7/15/15 12:16     G816     7070891        70401
# 4       2.020000e+11  7/15/15 12:16     G816     7090363        70401
# ...              ...            ...      ...         ...          ...
# 5377    2.020000e+11   9/5/15 23:07      300     7308017       210101
# 5378    2.020000e+11   9/5/15 23:23     G619     7070891        70401
# 5379    2.020000e+11   9/5/15 23:24     G619     7071096        70201
# 5380    2.020000e+11   9/5/15 23:32     G619    15000231        70301
# 5381    2.020000e+11   9/5/15 23:38     G619    23030206       210101
#
#       num_item  price
# 0          1.0    2.0
# 1          1.0    2.0
# 2          1.0    2.0
# 3          1.0    6.0
# ...

# %%
x=df_data['product_id'].unique()

# %%
x
# Out:
# array([ 7000300,  7070884,  7070891,  7090363,  7000126,  7308017,
#        15000231,  7071096,  7000133,  7071133,  7314599,  7000294,
#         7313684,  7071218,  7314612,  7090370, 21000782, 30000742,
#         7308765,  7000140,  7070969, 21000430,  7000034,  7000423,
#        21050107, 20098391, 30000759, 30000766,  7000409,  7090097,
#         7071102,  7071140,  7071164,  7000416, 21000447, 21000379,
#        21000362, 30000711,  7090462,  7090509,  7071331, 21050060,
#        21050022,  7090455,  7090592, 23030206,  7090493,  7071256,
#         7071249,  7090486,  7090479,  7071232,  7090615], dtype=int64)

# %%
print(f'there is {len(x)} different products in the DataFrame')
# Out:
# there is 53 different products in the DataFrame

# %%
x=num_rows['total'].describe().iloc[1]

# %%
x
# Out:
# 3.931807878112784

# %%
y=num_rows['total'].median()

# %%
print(f'the mean value of the total column is: {x}, while the median is: {y}. the difference between them is exactly: {x-y}')
# Out:
# the mean value of the total column is: 3.931807878112784, while the median is: 3.0. the difference between them is exactly: 0.9318078781127839

# %%
num_rows
# Out:
#       invoice_number  product_id  category_id  num_item  price  total
# 0       2.020000e+11     7000300       210101       1.0    2.0    2.0
# 1       2.020000e+11     7070884        70203       1.0    2.0    2.0
# 2       2.020000e+11     7070884        70203       1.0    2.0    2.0
# 3       2.020000e+11     7070891        70401       1.0    6.0    6.0
# 4       2.020000e+11     7090363        70401       1.0    6.0    6.0
# ...              ...         ...          ...       ...    ...    ...
# 5377    2.020000e+11     7308017       210101       1.0    3.0    3.0
# 5378    2.020000e+11     7070891        70401       1.0    6.0    6.0
# 5379    2.020000e+11     7071096        70201       1.0    5.0    5.0
# 5380    2.020000e+11    15000231        70301       2.0    2.0    4.0
# 5381    2.020000e+11    23030206       210101       1.0    2.0    2.0
#
# [5382 rows x 6 columns]

# %%
num_rows.drop('total',axis=1)
# Out:
#       invoice_number  product_id  category_id  num_item  price
# 0       2.020000e+11     7000300       210101       1.0    2.0
# 1       2.020000e+11     7070884        70203       1.0    2.0
# 2       2.020000e+11     7070884        70203       1.0    2.0
# 3       2.020000e+11     7070891        70401       1.0    6.0
# 4       2.020000e+11     7090363        70401       1.0    6.0
# ...              ...         ...          ...       ...    ...
# 5377    2.020000e+11     7308017       210101       1.0    3.0
# 5378    2.020000e+11     7070891        70401       1.0    6.0
# 5379    2.020000e+11     7071096        70201       1.0    5.0
# 5380    2.020000e+11    15000231        70301       2.0    2.0
# 5381    2.020000e+11    23030206       210101       1.0    2.0
#
# [5382 rows x 5 columns]

# %%
df_data
# Out:
#       invoice_number   invoice_time store_id  product_id  category_id  \
# 0       2.020000e+11  7/15/15 10:45     G816     7000300       210101
# 1       2.020000e+11  7/15/15 12:16     G816     7070884        70203
# 2       2.020000e+11  7/15/15 12:16     G816     7070884        70203
# 3       2.020000e+11  7/15/15 12:16     G816     7070891        70401
# 4       2.020000e+11  7/15/15 12:16     G816     7090363        70401
# ...              ...            ...      ...         ...          ...
# 5377    2.020000e+11   9/5/15 23:07      300     7308017       210101
# 5378    2.020000e+11   9/5/15 23:23     G619     7070891        70401
# 5379    2.020000e+11   9/5/15 23:24     G619     7071096        70201
# 5380    2.020000e+11   9/5/15 23:32     G619    15000231        70301
# 5381    2.020000e+11   9/5/15 23:38     G619    23030206       210101
#
#       num_item  price
# 0          1.0    2.0
# 1          1.0    2.0
# 2          1.0    2.0
# 3          1.0    6.0
# ...

# %%
df_data['invoice_time']=pd.to_datetime(df_data['invoice_time'],format='%m/%d/%y %H:%M')

# %%
df_data.dtypes
# Out:
# invoice_number           float64
# invoice_time      datetime64[ns]
# store_id                  object
# product_id                 int64
# category_id                int64
# num_item                 float64
# price                    float64
# dtype: object

# %%
df_data
# Out:
#       invoice_number        invoice_time store_id  product_id  category_id  \
# 0       2.020000e+11 2015-07-15 10:45:00     G816     7000300       210101
# 1       2.020000e+11 2015-07-15 12:16:00     G816     7070884        70203
# 2       2.020000e+11 2015-07-15 12:16:00     G816     7070884        70203
# 3       2.020000e+11 2015-07-15 12:16:00     G816     7070891        70401
# 4       2.020000e+11 2015-07-15 12:16:00     G816     7090363        70401
# ...              ...                 ...      ...         ...          ...
# 5377    2.020000e+11 2015-09-05 23:07:00      300     7308017       210101
# 5378    2.020000e+11 2015-09-05 23:23:00     G619     7070891        70401
# 5379    2.020000e+11 2015-09-05 23:24:00     G619     7071096        70201
# 5380    2.020000e+11 2015-09-05 23:32:00     G619    15000231        70301
# 5381    2.020000e+11 2015-09-05 23:38:00     G619    23030206       210101
#
#       num_item  price
# 0          1.0    2.0
# ...

# %%
df_data['DOW']=df_data['invoice_time'].dt.day_name()

# %%
df_data
# Out:
#       invoice_number        invoice_time store_id  product_id  category_id  \
# 0       2.020000e+11 2015-07-15 10:45:00     G816     7000300       210101
# 1       2.020000e+11 2015-07-15 12:16:00     G816     7070884        70203
# 2       2.020000e+11 2015-07-15 12:16:00     G816     7070884        70203
# 3       2.020000e+11 2015-07-15 12:16:00     G816     7070891        70401
# 4       2.020000e+11 2015-07-15 12:16:00     G816     7090363        70401
# ...              ...                 ...      ...         ...          ...
# 5377    2.020000e+11 2015-09-05 23:07:00      300     7308017       210101
# 5378    2.020000e+11 2015-09-05 23:23:00     G619     7070891        70401
# 5379    2.020000e+11 2015-09-05 23:24:00     G619     7071096        70201
# 5380    2.020000e+11 2015-09-05 23:32:00     G619    15000231        70301
# 5381    2.020000e+11 2015-09-05 23:38:00     G619    23030206       210101
#
#       num_item  price        DOW
# 0          1.0    2.0  Wednesday
# ...

# %%
df_data['Month']=df_data['invoice_time'].dt.month_name()

# %%
df_data.head()
# Out:
#    invoice_number        invoice_time store_id  product_id  category_id  \
# 0    2.020000e+11 2015-07-15 10:45:00     G816     7000300       210101
# 1    2.020000e+11 2015-07-15 12:16:00     G816     7070884        70203
# 2    2.020000e+11 2015-07-15 12:16:00     G816     7070884        70203
# 3    2.020000e+11 2015-07-15 12:16:00     G816     7070891        70401
# 4    2.020000e+11 2015-07-15 12:16:00     G816     7090363        70401
#
#    num_item  price        DOW Month
# 0       1.0    2.0  Wednesday  July
# 1       1.0    2.0  Wednesday  July
# 2       1.0    2.0  Wednesday  July
# 3       1.0    6.0  Wednesday  July
# 4       1.0    6.0  Wednesday  July

# %%
df_data['DOW'].value_counts()
# Out:
# DOW
# Wednesday    959
# Friday       906
# Thursday     828
# Saturday     800
# Tuesday      666
# Monday       616
# Sunday       607
# Name: count, dtype: int64

# %%
num_purchases_wed=df_data['DOW'].value_counts().iloc[0]

# %%
num_purchases_wed
# Out:
# 959

# %% [markdown]
# ## 2. Titanic DataFrame

# %%
df_titanic=pd.read_csv('Titanic.csv')

# %%
df_titanic.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
df_titanic.rename(columns={'Name':'Passenger_Name','Ticket':'Ticket_Num'},inplace=True)

# %%
df_titanic.head()
# Out:
#    PassengerId  Pclass                                Passenger_Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch Ticket_Num     Fare Cabin Embarked
# 0  34.5      0      0     330911   7.8292   NaN        Q
# 1  47.0      1      0     363272   7.0000   NaN        S
# 2  62.0      0      0     240276   9.6875   NaN        Q
# 3  27.0      0      0     315154   8.6625   NaN        S
# 4  22.0      1      1    3101298  12.2875   NaN        S

# %%
df_titanic.set_index('PassengerId',inplace=True)

# %%
df_titanic.head()
# Out:
#              Pclass                                Passenger_Name     Sex  \
# PassengerId
# 892               3                              Kelly, Mr. James    male
# 893               3              Wilkes, Mrs. James (Ellen Needs)  female
# 894               2                     Myles, Mr. Thomas Francis    male
# 895               3                              Wirz, Mr. Albert    male
# 896               3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#               Age  SibSp  Parch Ticket_Num     Fare Cabin Embarked
# PassengerId
# 892          34.5      0      0     330911   7.8292   NaN        Q
# 893          47.0      1      0     363272   7.0000   NaN        S
# 894          62.0      0      0     240276   9.6875   NaN        Q
# 895          27.0      0      0     315154   8.6625   NaN        S
# 896          22.0      1      1    3101298  12.2875   NaN        S

# %%
df_titanic['Passenger_Name'].loc[896]
# Out:
# 'Hirvonen, Mrs. Alexander (Helga E Lindqvist)'

# %%
# df_titanic.insert(0,'PassengerId',df_titanic.index)

# %%
df_titanic.head()
# Out:
#              Pclass                                Passenger_Name     Sex  \
# PassengerId
# 892               3                              Kelly, Mr. James    male
# 893               3              Wilkes, Mrs. James (Ellen Needs)  female
# 894               2                     Myles, Mr. Thomas Francis    male
# 895               3                              Wirz, Mr. Albert    male
# 896               3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#               Age  SibSp  Parch Ticket_Num     Fare Cabin Embarked
# PassengerId
# 892          34.5      0      0     330911   7.8292   NaN        Q
# 893          47.0      1      0     363272   7.0000   NaN        S
# 894          62.0      0      0     240276   9.6875   NaN        Q
# 895          27.0      0      0     315154   8.6625   NaN        S
# 896          22.0      1      1    3101298  12.2875   NaN        S

# %%
df_titanic.reset_index(inplace=True)

# %%
df_titanic.head()
# Out:
#    PassengerId  Pclass                                Passenger_Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch Ticket_Num     Fare Cabin Embarked
# 0  34.5      0      0     330911   7.8292   NaN        Q
# 1  47.0      1      0     363272   7.0000   NaN        S
# 2  62.0      0      0     240276   9.6875   NaN        Q
# 3  27.0      0      0     315154   8.6625   NaN        S
# 4  22.0      1      1    3101298  12.2875   NaN        S

# %%
df_titanic.isnull()
# Out:
#      PassengerId  Pclass  Passenger_Name    Sex    Age  SibSp  Parch  \
# 0          False   False           False  False  False  False  False
# 1          False   False           False  False  False  False  False
# 2          False   False           False  False  False  False  False
# 3          False   False           False  False  False  False  False
# 4          False   False           False  False  False  False  False
# ..           ...     ...             ...    ...    ...    ...    ...
# 413        False   False           False  False   True  False  False
# 414        False   False           False  False  False  False  False
# 415        False   False           False  False  False  False  False
# 416        False   False           False  False   True  False  False
# 417        False   False           False  False   True  False  False
#
#      Ticket_Num   Fare  Cabin  Embarked
# 0         False  False   True     False
# 1         False  False   True     False
# ...

# %%
df_titanic['Age'].isnull().sum()
# Out:
# 86

# %%
age_mean=df_titanic['Age'].mean()

# %%
age_mean
# Out:
# 30.272590361445783

# %%
df_titanic.fillna({"Age":age_mean}, inplace=True)

# %%
df_titanic
# Out:
#      PassengerId  Pclass                                Passenger_Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex       Age  SibSp  Parch          Ticket_Num      Fare Cabin  \
# ...

# %%
max_5_age=df_titanic['Age'].nlargest(5)

# %%
max_5_age
# Out:
# 96     76.0
# 81     67.0
# 179    64.0
# 236    64.0
# 305    64.0
# Name: Age, dtype: float64

# %%
mean_5_age=max_5_age.mean()

# %%
mean_5_age
# Out:
# 67.0
